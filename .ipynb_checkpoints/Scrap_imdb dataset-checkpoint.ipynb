# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
genres = ['Action', 'Drama', 'Thriller', 'Crime', 'Adventure', 'Comedy', 'Sci-Fi', 'Romance', 'Fantasy', 'Horror', 'War', 'Mystery', 'History', 'Animation', 'Western', 'Family', 'Sport', 'Biography', 'Musical', 'Music', 'Film-Noir', 'Reality-TV', 'Game-Show', 'News', 'Adult', 'Talk-Show']
lowercase_genres = [g.lower() for g in genres]
lowercase_genres
# Out:
# ['action',
#  'drama',
#  'thriller',
#  'crime',
#  'adventure',
#  'comedy',
#  'sci-fi',
#  'romance',
#  'fantasy',
#  'horror',
#  'war',
#  'mystery',
#  'history',
#  'animation',
#  'western',
#  'family',
#  'sport',
#  'biography',
#  'musical',
#  'music',
#  'film-noir',
#  'reality-tv',
#  'game-show',
#  'news',
#  'adult',
#  'talk-show']

# %%
data = {}

for genre in lowercase_genres:
    url = "https://www.imdb.com/search/title?genres=" + genre
    print(url)

    html = requests.get(url)
    soup = BeautifulSoup(html.text, 'html.parser')
    movie_div = soup.find_all('div', class_='lister-item mode-advanced')

    for movie in movie_div:
        title = movie.find('h3', class_='lister-item-header').find('a').text.strip()
        image_url = movie.find('img', class_='loadlate')['src']
        year = movie.find('span', class_='lister-item-year text-muted unbold').text.strip('()')
        
        certificate = movie.find('p', class_='text-muted').find('span', class_='certificate').text
        description = movie.find_all('p', class_='text-muted')[1].text.strip()
        rating = movie.find('div', class_='ratings-bar').find('strong').text

        director = movie.find('p', class_='').find_all('a')[0].text
        stars = [star.text for star in movie.find('p', class_='').find_all('a')[1:]]

        votes = movie.find('p', class_='sort-num_votes-visible').find('span', attrs={'name': 'nv'}).text

        data[title] = {
            'Title': title,
            'Image_URL': image_url,
            'Year': year,
            'Certificate': certificate,
            'Description': description,
            'Rating': rating,
            'Director': director,
            'Stars': stars,
            'Votes': votes
        }

        print('Title:', title)
        print('Year:', year)
        print('Image URL:', image_url)
        print('Certificate:', certificate)
        print('Description:', description)
        print('Rating:', rating)
        print('Director:', director)
        print('Stars:', stars)
        print('Votes:', votes)
        print('---')
# Out:
# https://www.imdb.com/search/title?genres=action
# Title: Indiana Jones and the Dial of Destiny
# Year: 2023
# Image URL: https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png
# Certificate: PG-13
# Description: Archaeologist Indiana Jones races against time to retrieve a legendary artifact that can change the course of history.
# Rating: 6.9
# Director: James Mangold
# Stars: ['Harrison Ford', 'Phoebe Waller-Bridge', 'Antonio Banderas', 'Karen Allen']
# Votes: 51,554
# ---
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16720/1070291011.py in <module>
#      14         year = movie.find('span', class_='lister-item-year text-muted unbold').text.strip('()')
#      15
# ---> 16         certificate = movie.find('p', class_='text-muted').find('span', class_='certificate').text
#      17         description = movie.find_all('p', class_='text-muted')[1].text.strip()
#      18         rating = movie.find('div', class_='ratings-bar').find('strong').text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
data = {}
count = 0

for genre in lowercase_genres:
    url = "https://www.imdb.com/search/title?genres=" + genre
    print(url)

    html = requests.get(url)
    print('Response:', html)
    soup = BeautifulSoup(html.text, 'html.parser')
    movie_div = soup.find_all('div', class_='lister-item mode-advanced')

    for movie in movie_div:
        if movie.find('h3', class_='lister-item-header').find('a') is not None:
            title_element = movie.find('h3', class_='lister-item-header').find('a')
            title = title_element.text.strip() if title_element else None
        else:
            title = None
            
        if movie.find('img', class_='loadlate') is not None:
            image_element = movie.find('img', class_='loadlate')
            image_url = image_element['src'] if image_element else None
        else:
            image_url = None

        if movie.find('span', class_='lister-item-year text-muted unbold') is not None:
            year_element = movie.find('span', class_='lister-item-year text-muted unbold')
            year = year_element.text.strip('()') if year_element else None
        else:
            year = None
        
        if movie.find('span', class_='certificate') is not None:
            certificate_element = movie.find('span', class_='certificate')
            certificate = certificate_element.text if certificate_element else None
        else:
            certificate = None
            
        if movie.find_all('p', class_='text-muted') is not None:
            description_element = movie.find_all('p', class_='text-muted')
            description = description_element[1].text.strip() if len(description_element) >= 2 else None
        else:
            description = None

        if movie.find('div', class_='ratings-bar') is not None:
            rating_element = movie.find('div', class_='ratings-bar').find('strong')
            rating = rating_element.text if rating_element else None
        else:
            rating = None

        if movie.find('p', class_='').find_all('a'):
            director_element = movie.find('p', class_='').find_all('a')
            director = director_element[0].text if director_element else None
            stars = [star.text for star in director_element[1:]] if director_element else None
        else: 
            director = None
            stars = None

        if movie.find('p', class_='sort-num_votes-visible').find('span', attrs={'name': 'nv'}) is not None:    
            votes_element = movie.find('p', class_='sort-num_votes-visible').find('span', attrs={'name': 'nv'})
            votes = votes_element.text if votes_element else None
        else:
            votes = None

        data[title] = {
            'Title': title,
            'Image_URL': image_url,
            'Year': year,
            'Certificate': certificate,
            'Description': description,
            'Rating': rating,
            'Director': director,
            'Stars': stars,
            'Votes': votes
        }

        print('Title:', title)
        print('Year:', year)
        print('Image URL:', image_url)
        print('Certificate:', certificate)
        print('Description:', description)
        print('Rating:', rating)
        print('Director:', director)
        print('Stars:', stars)
        print('Votes:', votes)
        print('---')
        count += 1
        print(count)
# Out:
# https://www.imdb.com/search/title?genres=action
# Response: <Response [200]>
# Title: Indiana Jones and the Dial of Destiny
# Year: 2023
# Image URL: https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png
# Certificate: PG-13
# Description: Archaeologist Indiana Jones races against time to retrieve a legendary artifact that can change the course of history.
# Rating: 6.9
# Director: James Mangold
# Stars: ['Harrison Ford', 'Phoebe Waller-Bridge', 'Antonio Banderas', 'Karen Allen']
# Votes: 48,640
# ---
# 1
# Title: The Witcher
# Year: 2019–
# Image URL: https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png
# Certificate: None
# Description: Geralt of Rivia, a solitary monster hunter, struggles to find his place in a world where people often prove more wicked than beasts.
# Rating: 8.1
# Director: Henry Cavill
# Stars: ['Freya Allan', 'Anya Chalotra', 'Eamon Farren']
# Votes: 527,847
# ---
# 2
# Title: Secret Invasion
# Year: 2023
# Image URL: https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png
# Certificate: None
# Description: Fury and Talos try to stop the Skrulls who have infiltrated the highest spheres of the Marvel Universe.
# Rating: 6.9
# Director: Samuel L. Jackson
# Stars: ['Ben Mendelsohn', 'Olivia Colman', 'Emilia Clarke']
# Votes: 13,432
# ---
# 3
# Title: The Flash
# Year: 2023
# Image URL: https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png
# Certificate: PG-13
# Description: Barry Allen uses his super speed to change the past, but his attempt to save his family creates a world without super heroes, forcing him to race for his life in order to save the future.
# Rating: 7.2
# Director: Andy Muschietti
# Stars: ['Ezra Miller', 'Michael Keaton', 'Sasha Calle', 'Michael Shannon']
# Votes: 82,664
# ---
# 4
# Title: Spider-Man: Across the Spider-Verse
# Year: 2023
# Image URL: https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png
# Certificate: PG
# Description: Miles Morales catapults across the Multiverse, where he encounters a team of Spider-People charged with protecting its very existence. When the heroes clash on how to handle a new threat, Miles must redefine what it means to be a hero.
# Rating: 8.9
# Director: Joaquim Dos Santos
# Stars: ['Kemp Powers', 'Justin K. Thompson', 'Shameik Moore', 'Hailee Steinfeld', 'Brian Tyree Henry', 'Luna Lauren Velez']
# Votes: 171,408
# ---
# 5
# Title: Extraction 2
# Year: 2023
# Image URL: https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png
# Certificate: R
# Description: After barely surviving his grievous wounds from his mission in Dhaka, Bangladesh, Tyler Rake is back, and his team is ready to take on their next mission.
# Rating: 7.1
# Director: Sam Hargrave
# Stars: ['Chris Hemsworth', 'Golshifteh Farahani', 'Adam Bessa', 'Tornike Gogrichiani']
# Votes: 84,166
# ---
# 6
# Title: Star Trek: Strange New Worlds
# Year: 2022–
# Image URL: https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png
# Certificate: None
# Description: A prequel to Star Trek: The Original Series, the show follows the crew of the USS Enterprise under Captain Christopher Pike.
# Rating: 8.2
# Director: Anson Mount
# Stars: ['Ethan Peck', 'Christina Chong', 'Melissa Navia']
# Votes: 42,032
# ---
# 7
# Title: Jack Ryan
# Year: 2018–2023
# Image URL: https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png
# Certificate: None
# Description: Up-and-coming CIA analyst, Jack Ryan, is thrust into dangerous field assignments.
# Rating: 8.0
# Director: John Krasinski
# Stars: ['Wendell Pierce', 'Michael Kelly', 'Abbie Cornish']
# Votes: 152,722
# ---
# 8
# Title: Avatar: The Way of Water
# Year: 2022
# Image URL: https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png
# Certificate: PG-13
# Description: Jake Sully lives with his newfound family formed on the extrasolar moon Pandora. Once a familiar threat returns to finish what was previously started, Jake must work with Neytiri and the army of the Na'vi race to protect their home.
# Rating: 7.6
# Director: James Cameron
# Stars: ['Sam Worthington', 'Zoe Saldana', 'Sigourney Weaver', 'Stephen Lang']
# Votes: 426,111
# ---
# 9
# Title: Game of Thrones
# Year: 2011–2019
# Image URL: https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png
# Certificate: A
# Description: Nine noble families fight for control over the lands of Westeros, while an ancient enemy returns after being dormant for millennia.
# Rating: 9.2
# Director: Emilia Clarke
# Stars: ['Peter Dinklage', 'Kit Harington', 'Lena Headey']
# Votes: 2,176,882
# ---
# 10
# Title: Transformers: Rise of the Beasts
# Year: 2023
# Image URL: https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png
# Certificate: PG-13
# Description: During the '90s, a new faction of Transformers - the Maximals - join the Autobots as allies in the battle for Earth.
# Rating: 6.5
# Director: Steven Caple Jr.
# Stars: ['Anthony Ramos', 'Dominique Fishback', 'Luna Lauren Velez', 'Dean Scott Vazquez']
# Votes: 33,954
# ---
# 11
# Title: Extraction
# Year: 2020
# Image URL: https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png
# Certificate: R
# Description: Tyler Rake, a fearless black market mercenary, embarks on the most deadly extraction of his career when he's enlisted to rescue the kidnapped son of an imprisoned international crime lord.
# Rating: 6.8
# Director: Sam Hargrave
# Stars: ['Chris Hemsworth', 'Bryon Lerum', 'Ryder Lerum', 'Rudhraksh Jaiswal']
# Votes: 237,255
# ---
# 12
# Title: John Wick: Chapter 4
# Year: 2023
# Image URL: https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png
# Certificate: R
# Description: John Wick uncovers a path to defeating The High Table. But before he can earn his freedom, Wick must face off against a new enemy with powerful alliances across the globe and forces that turn old friends into foes.
# Rating: 7.9
# Director: Chad Stahelski
# Stars: ['Keanu Reeves', 'Laurence Fishburne', 'George Georgiou', 'Lance Reddick']
# Votes: 232,596
# ---
# 13
# Title: Guy Ritchie's The Covenant
# Year: 2023
# Image URL: https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png
# Certificate: R
# Description: During the war in Afghanistan, a local interpreter risks his own life to carry an injured sergeant across miles of grueling terrain.
# Rating: 7.5
# Director: Guy Ritchie
# Stars: ['Jake Gyllenhaal', 'Dar Salim', 'Sean Sagar', 'Jason Wong']
# Votes: 74,105
# ---
# 14
# Title: Raiders of the Lost Ark
# Year: 1981
# Image URL: https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png
# Certificate: PG
# Description: In 1936, archaeologist and adventurer Indiana Jones is hired by the U.S. government to find the Ark of the Covenant before the Nazis can obtain its awesome powers.
# Rating: 8.4
# Director: Steven Spielberg
# Stars: ['Harrison Ford', 'Karen Allen', 'Paul Freeman', 'John Rhys-Davies']
# Votes: 998,812
# ---
# 15
# Title: Titans
# Year: I) (2018–2023
# Image URL: https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png
# Certificate: None
# Description: Dick and Rachel, a girl possessed by a strange darkness, get embroiled in a conspiracy that could bring Hell on Earth. Joining them along the way are the hot-headed Starfire and lovable Beast Boy. Together they become a team of heroes.
# Rating: 7.5
# Director: Brenton Thwaites
# Stars: ['Anna Diop', 'Ryan Potter', 'Teagan Croft']
# Votes: 107,837
# ---
# 16
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 58
#      55     director = None
#      56     stars = None
# ---> 58 if movie.find('p', class_='sort-num_votes-visible').find('span', attrs={'name': 'nv'}) is not None:
#      59     votes_element = movie.find('p', class_='sort-num_votes-visible').find('span', attrs={'name': 'nv'})
#      60     votes = votes_element.text if votes_element else None
#
# AttributeError: 'NoneType' object has no attribute 'find'
